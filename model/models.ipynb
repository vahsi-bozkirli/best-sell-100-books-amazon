# %%
import sklearn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from read_data import import_py_file
from warnings import filterwarnings

# %%
filterwarnings("ignore")

path = '../'
import_py_file(path)

import preprocessed_file as pf

# %%
read_data = pf.Data("../data/Top-100 Trending Books.csv",
                    "../data/customer reviews.csv")

# %%
top_books,custrew = read_data.added_features()

# %%
top_books
# Out:
#                                              book title  book price  rating  \
# Rank
# 1                          iron flame (the empyrean, 2)       18.42     4.1
# 2                                       the woman in me       20.93     4.5
# 3                                     my name is barbra       31.50     4.5
# 4     friends, lovers, and the big terrible thing: a...       23.99     4.4
# 5                                 how to catch a turkey        5.65     4.8
# ...                                                 ...         ...     ...
# 96    first little readers parent pack: guided readi...       11.40     4.7
# 97                                              hatchet        5.14     4.7
# 98    the wager: a tale of shipwreck, mutiny and murder       15.30     4.5
# 99    i'm dead, now what?: important information abo...       12.99     4.6
# 100                                    the wonky donkey        5.28     4.8
#
#                   author  year of publication  \
# Rank
# 1         rebecca yarros                 2023
# 2         britney spears                 2023
# 3       barbra streisand                 2023
# 4          matthew perry                 2023
# 5           adam wallace                 2018
# ...                  ...                  ...
# 96      deborah schecter                 2010
# 97          gary paulsen                 1987
# 98           david grann                 2023
# 99    peter pauper press                 2015
# 100          craig smith                 2009
#
#                                                   genre  \
# Rank
# 1                                       fantasy romance
# 2                                                memoir
# 3                                         autobiography
# 4                                                memoir
# 5                                    childrens, fiction
# ...                                                 ...
# 96                                           nonfiction
# 97     young adult novel, adventure novel, survival ...
# 98                                           nonfiction
# 99                                           nonfiction
# 100                            childrens, picture books
#
#                                                     url first_name  \
# Rank
# 1     amazon.com/iron-flame-empyrean-rebecca-yarros/...    rebecca
# 2     amazon.com/woman-me-britney-spears/dp/16680090...    britney
# 3     amazon.com/my-name-barbra-streisand/dp/0525429...     barbra
# 4     amazon.com/friends-lovers-big-terrible-thing/d...    matthew
# 5     amazon.com/how-catch-turkey-adam-wallace/dp/14...       adam
# ...                                                 ...        ...
# 96    amazon.com/first-little-readers-parent-pack/dp...    deborah
# 97    amazon.com/hatchet-gary-paulsen/dp/1416936475/...       gary
# 98    amazon.com/wager-tale-shipwreck-mutiny-murder/...      david
# 99    amazon.com/important-information-belongings-bu...      peter
# 100   amazon.com/wonky-donkey-craig-smith/dp/0545261...      craig
#
#          last_name  count genre        link  \
# Rank
# 1           yarros            2  amazon.com
# 2           spears            1  amazon.com
# 3        streisand            1  amazon.com
# 4            perry            1  amazon.com
# 5          wallace            2  amazon.com
# ...            ...          ...         ...
# 96        schecter            1  amazon.com
# 97         paulsen            8  amazon.com
# 98           grann            1  amazon.com
# 99    pauper press            1  amazon.com
# 100          smith            3  amazon.com
#
#                                                    book  dp          id  \
# Rank
# 1                    iron-flame-empyrean-rebecca-yarros  dp  1649374178
# 2                               woman-me-britney-spears  dp  1668009048
# 3                              my-name-barbra-streisand  dp  0525429522
# 4                     friends-lovers-big-terrible-thing  dp  1250866448
# 5                         how-catch-turkey-adam-wallace  dp  1492664359
# ...                                                 ...  ..         ...
# 96                     first-little-readers-parent-pack  dp  0545231493
# 97                                 hatchet-gary-paulsen  dp  1416936475
# 98                   wager-tale-shipwreck-mutiny-murder  dp  0385534264
# 99    important-information-belongings-business-affairs  dp  1441317996
# 100                            wonky-donkey-craig-smith  dp  0545261244
#
#                              ref                       slug
# Rank
# 1       ref=zg_bs_g_books_sccl_1  143-9831347-1043253?psc=1
# 2       ref=zg_bs_g_books_sccl_2  143-9831347-1043253?psc=1
# 3       ref=zg_bs_g_books_sccl_3  143-9831347-1043253?psc=1
# 4       ref=zg_bs_g_books_sccl_4  143-9831347-1043253?psc=1
# 5       ref=zg_bs_g_books_sccl_5  143-9831347-1043253?psc=1
# ...                          ...                        ...
# 96     ref=zg_bs_g_books_sccl_96  142-7825522-0098658?psc=1
# 97     ref=zg_bs_g_books_sccl_97  142-7825522-0098658?psc=1
# 98     ref=zg_bs_g_books_sccl_98  142-7825522-0098658?psc=1
# 99     ref=zg_bs_g_books_sccl_99  142-7825522-0098658?psc=1
# 100   ref=zg_bs_g_books_sccl_100  142-7825522-0098658?psc=1
#
# [100 rows x 16 columns]
